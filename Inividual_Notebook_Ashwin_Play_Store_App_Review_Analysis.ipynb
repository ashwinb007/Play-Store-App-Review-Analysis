# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwinb007/Play-Store-App-Review-Analysis/blob/main/Inividual_Notebook_Ashwin_Play_Store_App_Review_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Play Store App Review Analysis

# %% [markdown]
# **Project Type**    - EDA\
# **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **PlayStore**
#
# *Play Store and formerly Android Market, is a digital distribution service operated and developed by Google. It has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market.*

# %% [markdown]
# **Data**
#
# *In this notebook, we will do a comprehensive analysis of the Android app market and users review by comparing over ten thousand apps and reveiws repectively in Google Play across different categories. We'll look for insights in the data to devise strategies to drive growth and retention.*
#
# *Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.*
#
# *Also, we will explore and analyze the data to discover key factors responsible for app engagement and success.*

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/ashwinb007/Play-Store-App-Review-Analysis

# %% [markdown]
# # ***Let's Begin !***

# %%
# importing all the packages which we are going to use it.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#mounting the drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importing the data
play_store_df = pd.read_csv('/content/drive/MyDrive/Play Store Data.csv')
user_review_df = pd.read_csv('/content/drive/MyDrive/User Reviews.csv')

# %%
play_store_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
user_review_df
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %% [markdown]
# # <u> Data Exploration of Play Store Data

# %%
# we will see the first 5 rows of Playstore data
play_store_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# we will see the last 5 rows of Playstore data
play_store_df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
# we will see all the columns present in the data
play_store_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# we will be checking info of play store data
play_store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# we will see the details of numeric columns
play_store_df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# for checking shape of data
play_store_df.shape
# Out:
# (10841, 13)

# %% [markdown]
# # <u> Data Exploration of User reviews

# %%
# we will see the first 5 rows of User reviews
user_review_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
# we will see the last 5 rows of User reviews
user_review_df.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %%
# we will see all the columns present in the data
user_review_df.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# we will be checking info of User reviews data
user_review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
# we will see the details of numeric columns
user_review_df.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
# for checking shape of data
user_review_df.shape
# Out:
# (64295, 5)

# %% [markdown]
# #<u>Data cleaning

# %%
# here we will start cleaning the data of Playstore by removing all the duplicates
play_store_df.drop_duplicates(inplace = True)

# %%
# we will check whether there is any null values in the data.
play_store_df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
#we will check the null values for android version
play_store_df[play_store_df['Android Ver'].isnull()]
# Out:
#                                            App         Category  Rating  \
# 4453                    [substratum] Vacuum: P  PERSONALIZATION     4.4
# 4490                      Pi Dark [substratum]  PERSONALIZATION     4.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
#
#       Reviews    Size Installs  Type     Price Content Rating  \
# 4453      230     11M   1,000+  Paid     $1.49       Everyone
# 4490      189    2.1M  10,000+  Free         0       Everyone
# 10472    3.0M  1,000+     Free     0  Everyone            NaN
#
#                   Genres    Last Updated Current Ver Android Ver
# 4453     Personalization   July 20, 2018         4.4         NaN
# 4490     Personalization  March 27, 2018         1.1         NaN
# 10472  February 11, 2018          1.0.19  4.0 and up         NaN

# %%
# here we got to know that 1st two records are null values but the in third all the columns are misplaced. so we will drop it.
play_store_df.drop(10472,inplace = True)

# %%
#now we will change the null value of Android Version.
play_store_df['Android Ver'].fillna(play_store_df['Android Ver'].mode,inplace = True)

# %%
#we will check the null values for current version
play_store_df[play_store_df['Current Ver'].isnull()]
# Out:
#                                    App             Category  Rating Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2      55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1   20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2    4010
# 6803                         BT Master               FAMILY     NaN       0
# 7333                       Dots puzzle               FAMILY     4.0     179
# 7407                   Calculate My IQ               FAMILY     NaN      44
# 7730                            UFO-CQ                TOOLS     NaN       1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     NaN       8
#
#        Size    Installs  Type  Price Content Rating             Genres  \
# 15     2.7M      5,000+  Free      0       Everyone       Art & Design
# 1553    11k  1,000,000+  Free      0       Everyone   Libraries & Demo
# ...

# %%
#now we will change the null value of Current Version.
play_store_df['Current Ver'].fillna(play_store_df['Current Ver'].mode,inplace = True)

# %%
#same way we will do for Type column
play_store_df['Type'].fillna(play_store_df['Type'].mode,inplace = True)

# %%
#next we will fill the null values of ratings by median
play_store_df['Rating'].fillna(play_store_df['Rating'].median(),inplace = True)

# %%
#now we have filled all the null values as you can see below data.
play_store_df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
play_store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10357 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          10357 non-null  float64
#  3   Reviews         10357 non-null  object
#  4   Size            10357 non-null  object
#  5   Installs        10357 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10357 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  object
#  11  Current Ver     10357 non-null  object
#  12  Android Ver     10357 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# # now we need to change the following into numeric values.
#
#   Reviews\
#   Installs\
#   Price

# %%
play_store_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
play_store_df = play_store_df.astype({'Reviews' : int})

# %%
play_store_df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
# we will remove '+' and ',' so that we can convert into numerical value
play_store_df['Installs'] = play_store_df['Installs'].str.replace('+','').str.replace(',','')
play_store_df = play_store_df.astype({'Installs' : int})
# Out:
# <ipython-input-34-abcc437ba465>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   play_store_df['Installs'] = play_store_df['Installs'].str.replace('+','').str.replace(',','')

# %%
play_store_df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
# we will remove '$' so that we can convert into numerical value
play_store_df['Price'] = play_store_df['Price'].str.replace('$','')
play_store_df = play_store_df.astype({'Price' : float})
# Out:
# <ipython-input-36-483d3c9f2692>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   play_store_df['Price'] = play_store_df['Price'].str.replace('$','')

# %%
# u can see here we got the numerical values.
play_store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10357 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          10357 non-null  float64
#  3   Reviews         10357 non-null  int64
#  4   Size            10357 non-null  object
#  5   Installs        10357 non-null  int64
#  6   Type            10357 non-null  object
#  7   Price           10357 non-null  float64
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  object
#  11  Current Ver     10357 non-null  object
#  12  Android Ver     10357 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
# this the the final dataframe of playstore where we will do the analysis.
play_store_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# now we will start cleaning the data of User reviews.
# we will remove all the duplicates
user_review_df.drop_duplicates(inplace = True)

# %%
user_review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30679 entries, 0 to 64236
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     30679 non-null  object
#  1   Translated_Review       29692 non-null  object
#  2   Sentiment               29697 non-null  object
#  3   Sentiment_Polarity      29697 non-null  float64
#  4   Sentiment_Subjectivity  29697 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.4+ MB

# %%
user_review_df.isnull().sum()
# Out:
# App                         0
# Translated_Review         987
# Sentiment                 982
# Sentiment_Polarity        982
# Sentiment_Subjectivity    982
# dtype: int64

# %%
user_review_df['Sentiment'].unique()
# Out:
# array(['Positive', nan, 'Neutral', 'Negative'], dtype=object)

# %%
# we are going to remove all the rows whose sentiments are null.
user_review_df = user_review_df[~user_review_df['Sentiment'].isna()]

# %%
user_review_df.isnull().sum()
# Out:
# App                       0
# Translated_Review         5
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
user_review_df.fillna(0,inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
# this the the final dataframe of playstore where we will do the analysis.
user_review_df
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %% [markdown]
# # <b><u>we have cleaned the both data and we gonna start analysing these data.

# %% [markdown]
# # Top Content Rating Values

# %%
Crv_graph = sns.countplot(play_store_df['Content Rating'])
plt.rcParams['figure.figsize'] = (15, 10)
plt.title('Number of Apps based on Content Rating')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **INFERENCE:** As we can see in the plot, the most number of apps by Content rating is for everyone. Everyone can use most of the apps. And apps which is based on least content Ratings are of ' Adults only 18+' and 'Unrated' as there are only fews apps apps available of these two content ratings.

# %% [markdown]
# # Distribution of Ratings

# %%
Dor_graph = sns.countplot(play_store_df['Rating'])
plt.rcParams['figure.figsize'] = (15, 10)
plt.title('Count of Ratings')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **INFERENCE:** We found out that most of the apps ratings are between 4.2 and 4.6. Maximum numbers of apps rated is 4.5. There are very fews apps which is rated less than 3.6.

# %% [markdown]
# #Revenue generated by Top Categories

# %%
#Revenue = Price * Installs
play_store_df['Revenue'] = play_store_df['Price'] * play_store_df['Installs']

# %%
play_store_df.sort_values(by="Revenue",ascending=False).head()
# Out:
#                     App   Category  Rating  Reviews                Size  \
# 2241          Minecraft     FAMILY     4.5  2376564  Varies with device
# 4347          Minecraft     FAMILY     4.5  2375336  Varies with device
# 5351          I am rich  LIFESTYLE     3.8     3547                1.8M
# 5356  I Am Rich Premium    FINANCE     4.1     1867                4.7M
# 4034      Hitman Sniper       GAME     4.6   408292                 29M
#
#       Installs  Type   Price Content Rating                     Genres  \
# 2241  10000000  Paid    6.99   Everyone 10+  Arcade;Action & Adventure
# 4347  10000000  Paid    6.99   Everyone 10+  Arcade;Action & Adventure
# 5351    100000  Paid  399.99       Everyone                  Lifestyle
# 5356     50000  Paid  399.99       Everyone                    Finance
# 4034  10000000  Paid    0.99     Mature 17+                     Action
#
#            Last Updated Current Ver         Android Ver     Revenue
# ...

# %%
play_store_df[["App","Revenue","Category"]]
# Out:
#                                                      App  Revenue  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook      0.0
# 1                                    Coloring book moana      0.0
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...      0.0
# 3                                  Sketch - Draw & Paint      0.0
# 4                  Pixel Draw - Number Art Coloring Book      0.0
# ...                                                  ...      ...
# 10836                                   Sya9a Maroc - FR      0.0
# 10837                   Fr. Mike Schmitz Audio Teachings      0.0
# 10838                             Parkinson Exercices FR      0.0
# 10839                      The SCP Foundation DB fr nn5n      0.0
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology      0.0
#
#                   Category
# 0           ART_AND_DESIGN
# 1           ART_AND_DESIGN
# 2           ART_AND_DESIGN
# 3           ART_AND_DESIGN
# 4           ART_AND_DESIGN
# ...

# %%
revenue_category = play_store_df.groupby("Category",as_index=False)["Revenue"].sum().sort_values(by="Revenue",ascending=False).head(15)
revenue_category
# Out:
#                Category       Revenue
# 11               FAMILY  1.857803e+08
# 18            LIFESTYLE  5.758394e+07
# 14                 GAME  4.098764e+07
# 12              FINANCE  2.572668e+07
# 24          PHOTOGRAPHY  8.942768e+06
# 20              MEDICAL  8.456536e+06
# 23      PERSONALIZATION  7.786948e+06
# 29                TOOLS  5.464821e+06
# 28               SPORTS  4.706212e+06
# 25         PRODUCTIVITY  4.313375e+06
# 6         COMMUNICATION  4.247364e+06
# 32              WEATHER  4.181380e+06
# 8             EDUCATION  2.403980e+06
# 15   HEALTH_AND_FITNESS  1.426069e+06
# 19  MAPS_AND_NAVIGATION  1.240789e+06

# %%
sns.barplot(x=revenue_category["Revenue"],y=revenue_category["Category"],data=revenue_category)
plt.title("Revenue generated by Top Category",fontsize=20)
plt.show()

# %% [markdown]
# **INFERENCE:** From this graph, we can understand that the Category who generated the highest revenue is 'Family' followed by 'Lifestyle' and 'Game'.

# %% [markdown]
# # App Price across Categories

# %%
papc = sns.stripplot(x = play_store_df['Price'], y = play_store_df['Category'], linewidth=1 , size=8)
papc.set_title('Trend of App Price across categories',size=30)
plt.show()

# %% [markdown]
# **Inference:** We can understand from these graphs that the top prices are of 'Family', 'Lifestyle', and 'Finance' categories.

# %% [markdown]
# # Correlation of both the Datas

# %%
# now we will merge both data for more analysis.
whole_df = play_store_df.merge(user_review_df, on="App")
whole_df.head()
# Out:
#                    App        Category  Rating  Reviews Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9      967  14M    500000  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9      967  14M    500000  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9      967  14M    500000  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9      967  14M    500000  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9      967  14M    500000  Free
#
#    Price Content Rating                     Genres      Last Updated  \
# 0    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 3    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 4    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver  Revenue  \
# 0       2.0.0  4.0.3 and up      0.0
# ...

# %%
whole_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40422 entries, 0 to 40421
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     40422 non-null  object
#  1   Category                40422 non-null  object
#  2   Rating                  40422 non-null  float64
#  3   Reviews                 40422 non-null  int64
#  4   Size                    40422 non-null  object
#  5   Installs                40422 non-null  int64
#  6   Type                    40422 non-null  object
#  7   Price                   40422 non-null  float64
#  8   Content Rating          40422 non-null  object
#  9   Genres                  40422 non-null  object
#  10  Last Updated            40422 non-null  object
#  11  Current Ver             40422 non-null  object
#  12  Android Ver             40422 non-null  object
#  13  Revenue                 40422 non-null  float64
# ...

# %%
sns.heatmap(whole_df.corr(),annot = True,cmap='Greens')
plt.title("Correlation on merge datas",fontsize=20)
plt.show()

# %% [markdown]
# **Inference:** The above plot shows the correlation of both the datas i.e Play Store data and User Review Data. We found that the most of the correlations between variables are positive and only some are negative.

# %% [markdown]
# # Age vs Sentiments

# %%
avs = sns.countplot(whole_df["Content Rating"],hue=whole_df['Sentiment'],palette="Set3")
plt.title("Age vs Sentiment",size=15)
for p in avs.patches:
    avs.annotate(p.get_height(),(p.get_x() + p.get_width()/2,p.get_height()),ha='center',size= 12)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Inference:** From this graph, we can understand that most sentiments are from 'everyone'. which is positive. followed by negative. The second most sentiments are from 'Teen'.

# %% [markdown]
# # Conclusions-

# %% [markdown]
# * The most number of apps by Content rating is for everyone. Everyone can use most of the apps. And apps which is based on least content Ratings are of ' Adults only 18+' and 'Unrated' as there are only fews apps apps available of these two content ratings.
# * We found out that most of the apps ratings are between 4.2 and 4.6. Maximum numbers of apps rated is 4.5. There are very fews apps which is rated less than 3.6.
# * The Category who generated the highest revenue is 'Family' followed by 'Lifestyle' and 'Game'.
# * The top prices are of 'Family', 'Lifestyle', and 'Finance' categories.
# * The most of the correlations between variables are positive and only some are negative.
# * The most sentiments are from 'everyone'. which is positive. followed by negative. The second most sentiments are from 'Teen'.
